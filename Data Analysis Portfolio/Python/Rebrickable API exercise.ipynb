# %%
import requests
import pandas as pd

# %%
# initial setup


API_KEY = "c00b9ef4ffd9618f720ad53b79692959"
BASE_URL = "https://rebrickable.com/api/v3/lego"

headers = {
    "Authorization": f"key {API_KEY}"
}

# %%
# making a simple request without pagination

url = f"{BASE_URL}/sets/"
params = {
    "search": "technic",
    "page_size": 50
}

response = requests.get(url, headers=headers, params=params)
data = response.json()

# %%
data.keys()
